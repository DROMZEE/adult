# %% [markdown]
# # Dataset adult

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-des-lib" data-toc-modified-id="Import-des-lib-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import des lib</a></span></li><li><span><a href="#Import-des-données" data-toc-modified-id="Import-des-données-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import des données</a></span></li><li><span><a href="#Analyse-exploratoire" data-toc-modified-id="Analyse-exploratoire-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Analyse exploratoire</a></span><ul class="toc-item"><li><span><a href="#découverte-des-données" data-toc-modified-id="découverte-des-données-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>découverte des données</a></span></li><li><span><a href="#Valeurs-dupliquées" data-toc-modified-id="Valeurs-dupliquées-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Valeurs dupliquées</a></span></li><li><span><a href="#valeurs-manquantes" data-toc-modified-id="valeurs-manquantes-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>valeurs manquantes</a></span></li><li><span><a href="#Visualisation" data-toc-modified-id="Visualisation-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Visualisation</a></span><ul class="toc-item"><li><span><a href="#age" data-toc-modified-id="age-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>age</a></span></li><li><span><a href="#Education" data-toc-modified-id="Education-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Education</a></span></li><li><span><a href="#Marital-Status" data-toc-modified-id="Marital-Status-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Marital Status</a></span></li><li><span><a href="#Occupation" data-toc-modified-id="Occupation-3.4.4"><span class="toc-item-num">3.4.4&nbsp;&nbsp;</span>Occupation</a></span></li><li><span><a href="#workclass" data-toc-modified-id="workclass-3.4.5"><span class="toc-item-num">3.4.5&nbsp;&nbsp;</span>workclass</a></span></li><li><span><a href="#sex" data-toc-modified-id="sex-3.4.6"><span class="toc-item-num">3.4.6&nbsp;&nbsp;</span>sex</a></span></li><li><span><a href="#salaire" data-toc-modified-id="salaire-3.4.7"><span class="toc-item-num">3.4.7&nbsp;&nbsp;</span>salaire</a></span></li><li><span><a href="#capital-gain" data-toc-modified-id="capital-gain-3.4.8"><span class="toc-item-num">3.4.8&nbsp;&nbsp;</span>capital-gain</a></span></li><li><span><a href="#Capital-Loss" data-toc-modified-id="Capital-Loss-3.4.9"><span class="toc-item-num">3.4.9&nbsp;&nbsp;</span>Capital Loss</a></span></li><li><span><a href="#Hours-per-week" data-toc-modified-id="Hours-per-week-3.4.10"><span class="toc-item-num">3.4.10&nbsp;&nbsp;</span>Hours per week</a></span></li><li><span><a href="#Relationship" data-toc-modified-id="Relationship-3.4.11"><span class="toc-item-num">3.4.11&nbsp;&nbsp;</span>Relationship</a></span></li><li><span><a href="#Race" data-toc-modified-id="Race-3.4.12"><span class="toc-item-num">3.4.12&nbsp;&nbsp;</span>Race</a></span></li><li><span><a href="#native-country" data-toc-modified-id="native-country-3.4.13"><span class="toc-item-num">3.4.13&nbsp;&nbsp;</span>native-country</a></span></li></ul></li><li><span><a href="#Valeurs-inutiles" data-toc-modified-id="Valeurs-inutiles-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Valeurs inutiles</a></span></li><li><span><a href="#dummies" data-toc-modified-id="dummies-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>dummies</a></span></li></ul></li><li><span><a href="#Split" data-toc-modified-id="Split-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Split</a></span></li><li><span><a href="#Modélisation" data-toc-modified-id="Modélisation-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Modélisation</a></span><ul class="toc-item"><li><span><a href="#LogisticRegression" data-toc-modified-id="LogisticRegression-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>LogisticRegression</a></span><ul class="toc-item"><li><span><a href="#Accuracy-score" data-toc-modified-id="Accuracy-score-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Accuracy score</a></span></li><li><span><a href="#Classification-report" data-toc-modified-id="Classification-report-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Classification report</a></span></li><li><span><a href="#Matrice-de-confusion" data-toc-modified-id="Matrice-de-confusion-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Matrice de confusion</a></span></li><li><span><a href="#Coefficients" data-toc-modified-id="Coefficients-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>Coefficients</a></span></li><li><span><a href="#ROC" data-toc-modified-id="ROC-5.1.5"><span class="toc-item-num">5.1.5&nbsp;&nbsp;</span>ROC</a></span></li><li><span><a href="#predict" data-toc-modified-id="predict-5.1.6"><span class="toc-item-num">5.1.6&nbsp;&nbsp;</span>predict</a></span></li></ul></li><li><span><a href="#DecisionTreeClassifier" data-toc-modified-id="DecisionTreeClassifier-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>DecisionTreeClassifier</a></span></li><li><span><a href="#ExtraTreesClassifier" data-toc-modified-id="ExtraTreesClassifier-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>ExtraTreesClassifier</a></span></li><li><span><a href="#KFold" data-toc-modified-id="KFold-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>KFold</a></span></li></ul></li><li><span><a href="#pipeline" data-toc-modified-id="pipeline-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>pipeline</a></span></li><li><span><a href="#GridSearchCV" data-toc-modified-id="GridSearchCV-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>GridSearchCV</a></span><ul class="toc-item"><li><span><a href="#reg-log" data-toc-modified-id="reg-log-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>reg log</a></span></li><li><span><a href="#KNN" data-toc-modified-id="KNN-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>KNN</a></span></li></ul></li><li><span><a href="#liens" data-toc-modified-id="liens-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>liens</a></span></li></ul></div>

# %% [markdown]
# ## Import des lib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Import des données

# %% [markdown]
# Source : https://archive.ics.uci.edu/ml/datasets/Adult

# %%
liste = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status','occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'salaire']
adult = pd.read_csv('data/adult.data',engine='python', sep=' *, *', names=liste, index_col=False, na_values='?' )
data_test = pd.read_csv('data/adult.test',engine='python', sep=' *, *', names=liste, index_col=False, na_values='?', skiprows = 1 )

# %% [markdown]
# ## Analyse exploratoire

# %% [markdown]
# * age: continuous.
# * workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * fnlwgt: continuous.
# * education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * education-num: continuous.
# * marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# * sex: Female, Male.
# * capital-gain: continuous.
# * capital-loss: continuous.
# * hours-per-week: continuous.
# * native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %% [markdown]
# Predict whether income exceeds $50K/yr based on census data. Also known as "Census Income" dataset

# %% [markdown]
# ### découverte des données

# %%
adult.shape
# Out:
# (32561, 15)

# %%
adult.head(3)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
#
#        marital-status         occupation   relationship   race   sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White  Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White  Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White  Male
#
#    capital-gain  capital-loss  hours-per-week native-country salaire
# 0          2174             0              40  United-States   <=50K
# 1             0             0              13  United-States   <=50K
# 2             0             0              40  United-States   <=50K

# %%
adult.count()
# Out:
# age               32561
# workclass         30725
# fnlwgt            32561
# education         32561
# education-num     32561
# marital-status    32561
# occupation        30718
# relationship      32561
# race              32561
# sex               32561
# capital-gain      32561
# capital-loss      32561
# hours-per-week    32561
# native-country    31978
# salaire           32561
# dtype: int64

# %%
type(adult)
# Out:
# pandas.core.frame.DataFrame

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  31978 non-null  object
#  14  salaire         32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
adult.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ### Valeurs dupliquées

# %%
adult.shape, adult.drop_duplicates().shape
# Out:
# ((32561, 15), (32537, 15))

# %%
adult = pd.DataFrame(adult.drop_duplicates())

# %%
type(data)
# Out:
# tuple

# %%
adult.shape
# Out:
# (32537, 15)

# %%
adult.head(3)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
#
#        marital-status         occupation   relationship   race   sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White  Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White  Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White  Male
#
#    capital-gain  capital-loss  hours-per-week native-country salaire
# 0          2174             0              40  United-States   <=50K
# 1             0             0              13  United-States   <=50K
# 2             0             0              40  United-States   <=50K

# %% [markdown]
# ### valeurs manquantes

# %%
pd.isnull(adult).sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     582
# salaire              0
# dtype: int64

# %%
adult.count()
# Out:
# age               32537
# workclass         30701
# fnlwgt            32537
# education         32537
# education-num     32537
# marital-status    32537
# occupation        30694
# relationship      32537
# race              32537
# sex               32537
# capital-gain      32537
# capital-loss      32537
# hours-per-week    32537
# native-country    31955
# salaire           32537
# dtype: int64

# %%
import missingno as msno

# %%
msno.matrix(adult)

# %%
msno.heatmap(adult)

# %% [markdown]
# ### Visualisation

# %%
sns.pairplot(adult)

# %% [markdown]
# #### age

# %%
ageData = adult['age'].value_counts().to_dict()
xAxis = [key for key in ageData]
yAxis = [ageData[key] for key in ageData]
plt.scatter(xAxis, yAxis)
plt.xlabel('Age')
plt.ylabel('individus');

# %% [markdown]
# La majorité des individus ont entre 20 et 50 ans

# %%
ageTargetData = {}
for index, element in enumerate(adult['age']):
    if index in adult['salaire']:
        if element not in ageTargetData:
            if adult['salaire'][index] == '-1':
                ageTargetData[element] = [1,0]
            else:
                ageTargetData[element] = [0,1]
        else:
            if adult['salaire'][index] == '1':
                ageTargetData[element][0] +=1
            else:
                ageTargetData[element][1] += 1

xAxis = [key for key in ageTargetData]
y1Axis = [100*ageTargetData[key][0]/(ageTargetData[key][0]+ageTargetData[key][1]) for key in ageTargetData]
y2Axis = [100*ageTargetData[key][1]/(ageTargetData[key][0]+ageTargetData[key][1]) for key in ageTargetData]


plt.scatter(xAxis, y1Axis, label = '<=50K', color = 'red')
plt.scatter(xAxis, y2Axis, label = '>50K', color = 'green')
plt.legend()

plt.xlabel('Age')
plt.ylabel('Percentage of people who\n earn more or less than 50k');

# %% [markdown]
# #### Education

# %%
# %config InlineBackend.figure_format = 'svg'
adult['education'].value_counts().plot(kind='bar')
plt.xlabel('Education')
plt.ylabel('Amount of people');

# %% [markdown]
# #### Marital Status

# %%
adult['marital-status'].value_counts().plot(kind='bar')
plt.xlabel('Marital Status')
plt.ylabel('Amount of people');

# %%
marriageTargetData = {}
for index, element in enumerate(adult['marital-status']):
    if index in adult['salaire']:
        if element not in marriageTargetData:
            if adult['salaire'][index] == '<=50K':
                marriageTargetData[element] = [1,0]
            else:
                marriageTargetData[element] = [0,1]
        else:
            if adult['salaire'][index] == '<=50K':
                marriageTargetData[element][0] +=1
            else:
                marriageTargetData[element][1] += 1

            
xAxis = [key for key in marriageTargetData]
y1Axis = [marriageTargetData[key][0]/(marriageTargetData[key][0]+marriageTargetData[key][1]) for key in marriageTargetData]
y2Axis = [marriageTargetData[key][1]/(marriageTargetData[key][0]+marriageTargetData[key][1]) for key in marriageTargetData]

plt.scatter(xAxis, y1Axis, label = '<=50K', color = 'red')
plt.scatter(xAxis, y2Axis, label = '>50K', color = 'green')
plt.xticks(rotation=90)
plt.legend()

plt.xlabel('Marital Status')
plt.ylabel('Percentage of people who\n earn more or less than 50k');

# %% [markdown]
# #### Occupation

# %%
adult['occupation'].value_counts().plot(kind='bar')
plt.xlabel('Occupation')
plt.ylabel('Amount of people');

# %% [markdown]
# #### workclass

# %%
adult.workclass.unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', nan, 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
adult['workclass'].value_counts().plot(kind='bar')
plt.xlabel('Work Class')
plt.ylabel('Amount of people');

# %% [markdown]
# #### sex

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(10,4))

adult['sex'].value_counts().plot(kind='pie', ax = ax1)
plt.xlabel('Sex')
plt.ylabel('Amount of people');

adult["sex"].value_counts().plot(kind="bar", ax=ax2)

# %%
adult.sex = adult.sex.map({"Male": 0, "Female":1})

# %%
adult.head(3)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
#
#        marital-status         occupation   relationship   race  sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    0
# 1  Married-civ-spouse    Exec-managerial        Husband  White    0
# 2            Divorced  Handlers-cleaners  Not-in-family  White    0
#
#    capital-gain  capital-loss  hours-per-week native-country salaire
# 0          2174             0              40  United-States   <=50K
# 1             0             0              13  United-States   <=50K
# 2             0             0              40  United-States   <=50K

# %% [markdown]
# #### salaire

# %%
adult["salaire"] = adult["salaire"].map({ "<=50K": -1, ">50K": 1 })

# %% [markdown]
# #### capital-gain

# %%
adult["capital-gain"].value_counts()
# Out:
# 0        29825
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 4931         1
# 1455         1
# 6097         1
# 22040        1
# 1111         1
# Name: capital-gain, Length: 119, dtype: int64

# %%
gainData = adult['capital-gain'].value_counts().to_dict()
xAxis = [key for key in gainData]
yAxis = [gainData[key] for key in gainData]
plt.scatter(xAxis, yAxis)
plt.xlabel('Capital Gain')
plt.ylabel('Amount of people');

# %%
#adult.drop("capital-gain", axis=1, inplace=True)
#adult.drop("capital-loss", axis=1, inplace=True)

# %% [markdown]
# #### Capital Loss

# %%
lossData = adult['capital-loss'].value_counts().to_dict()
xAxis = [key for key in lossData]
yAxis = [lossData[key] for key in lossData]
plt.scatter(xAxis, yAxis)
plt.xlabel('Capital Loss')
plt.ylabel('Amount of people');

# %% [markdown]
# #### Hours per week

# %%
hoursData = adult['hours-per-week'].value_counts().to_dict()
xAxis = [key for key in hoursData]
yAxis = [hoursData[key] for key in hoursData]
plt.scatter(xAxis, yAxis)
plt.xlabel('Hours per week')
plt.ylabel('Amount of people');

# %% [markdown]
# #### Relationship

# %%
adult['relationship'].value_counts().plot(kind='bar')
plt.xlabel('Relationship')
plt.ylabel('Amount of people');

# %% [markdown]
# #### Race

# %%
adult['race'].value_counts().plot(kind='bar')
plt.xlabel('Race')
plt.ylabel('Amount of people');

# %% [markdown]
# #### native-country

# %%
len(adult["native-country"].unique())
# Out:
# 42

# %%
adult['native-country'].value_counts().plot(kind='bar')
plt.xlabel('Country')
plt.ylabel('Amount of people');

# %%
adult["native-country"].value_counts()
# Out:
# United-States                 29153
# Mexico                          639
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# ...

# %%
adult = adult[adult["native-country"] != "Holand-Netherlands"]

# %% [markdown]
# ### Valeurs inutiles

# %%
adult["fnlwgt"].dropna(axis=0, inplace=True)

# %% [markdown]
# ### dummies

# %%
workclass_dummies = pd.get_dummies(adult.workclass, prefix="workclass", drop_first=True)
education_dummies = pd.get_dummies(adult.education, prefix="education", drop_first=True)
maritalstatus_dummies = pd.get_dummies(adult["marital-status"], prefix="marital-status", drop_first=True)
occupation_dummies = pd.get_dummies(adult.occupation, prefix="occupation", drop_first=True)
relationship_dummies = pd.get_dummies(adult.relationship, prefix="relationship", drop_first=True)
race_dummies = pd.get_dummies(adult.race, prefix="race", drop_first=True)
nativecountry_dummies = pd.get_dummies(adult["native-country"], prefix="native-country", drop_first=True)

# %%
adult_dum = pd.concat([adult, 
                       workclass_dummies, 
                       education_dummies, 
                       maritalstatus_dummies, 
                       occupation_dummies, 
                       relationship_dummies,
                       race_dummies,
                       nativecountry_dummies], axis=1)

# %%
adult_dum.drop(["workclass", "education", "marital-status", "occupation", "relationship",
    "race", "native-country"], axis=1, inplace=True)

# %%
adult_dum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 98 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   age                                        32537 non-null  int64
#  1   fnlwgt                                     32537 non-null  int64
#  2   education-num                              32537 non-null  int64
#  3   sex                                        32537 non-null  int64
#  4   capital-gain                               32537 non-null  int64
#  5   capital-loss                               32537 non-null  int64
#  6   hours-per-week                             32537 non-null  int64
#  7   salaire                                    32537 non-null  int64
#  8   workclass_Local-gov                        32537 non-null  uint8
#  9   workclass_Never-worked                     32537 non-null  uint8
# ...

# %%
type(adult_dum)
# Out:
# pandas.core.frame.DataFrame

# %%
adult_dum.drop("fnlwgt", axis = 1, inplace=True)

# %%
adult_dum.head()
# Out:
#    age  education-num  sex  capital-gain  capital-loss  hours-per-week  \
# 0   39             13    0          2174             0              40
# 1   50             13    0             0             0              13
# 2   38              9    0             0             0              40
# 3   53              7    0             0             0              40
# 4   28             13    1             0             0              40
#
#    salaire  workclass_Local-gov  workclass_Never-worked  workclass_Private  \
# 0       -1                    0                       0                  0
# 1       -1                    0                       0                  0
# 2       -1                    0                       0                  1
# 3       -1                    0                       0                  1
# 4       -1                    0                       0                  1
#
#    ...  native-country_Portugal  native-country_Puerto-Rico  \
# ...

# %% [markdown]
# ## Split

# %%
X = adult_dum.drop('salaire', axis=1)
y = adult_dum['salaire']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %%
X_train.head(4)
# Out:
#        age  education-num  sex  capital-gain  capital-loss  hours-per-week  \
# 26677   60             10    0             0             0              50
# 29875   18              7    1             0             0              20
# 15269   62              9    1             0             0              38
# 27228   38              9    1             0             0              25
#
#        workclass_Local-gov  workclass_Never-worked  workclass_Private  \
# 26677                    0                       0                  1
# 29875                    0                       0                  1
# 15269                    0                       0                  1
# 27228                    0                       0                  1
#
#        workclass_Self-emp-inc  ...  native-country_Portugal  \
# 26677                       0  ...                        0
# 29875                       0  ...                        0
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
std = StandardScaler()
X_train = std.fit_transform(X_train)
X_test = std.fit_transform(X_test)

# %% [markdown]
# ## Modélisation

# %% [markdown]
# ### LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
reglog = LogisticRegression(solver='liblinear')
reglog.fit(X_train, y_train)

# Prédictions sur le test set
y_pred = reglog.predict(X_test)

# %% [markdown]
# #### Accuracy score

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8538414259373079

# %% [markdown]
# #### Classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.89      0.92      0.91      6243
#            1       0.71      0.62      0.67      1892
#
#     accuracy                           0.85      8135
#    macro avg       0.80      0.77      0.79      8135
# weighted avg       0.85      0.85      0.85      8135

# %% [markdown]
# #### Matrice de confusion

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[5765  478]
#  [ 711 1181]]

# %% [markdown]
# #### Coefficients

# %%
# Coefficients
coef = pd.DataFrame(np.concatenate([reglog.intercept_.reshape(-1,1), reglog.coef_],axis=1),
             index = ["Coefficients"],
             columns = ["constante"]+list(X.columns)).T

coef["OR"] = np.exp(coef.Coefficients)
coef["1/OR"] = np.exp(-coef.Coefficients)
coef
# Out:
#                                 Coefficients         OR      1/OR
# constante                          -2.072824   0.125830  7.947234
# age                                 0.339132   1.403729  0.712388
# education-num                       0.586623   1.797907  0.556202
# sex                                -0.377536   0.685549  1.458686
# capital-gain                        2.381258  10.818508  0.092434
# ...                                      ...        ...       ...
# native-country_Thailand            -0.007377   0.992650  1.007404
# native-country_Trinadad&Tobago     -0.002283   0.997720  1.002285
# native-country_United-States        0.137346   1.147225  0.871669
# native-country_Vietnam             -0.038789   0.961953  1.039552
# native-country_Yugoslavia           0.000312   1.000313  0.999688
#
# [97 rows x 3 columns]

# %% [markdown]
# #### ROC

# %%
# Courbe ROC
from sklearn.metrics import roc_curve, auc
proba = reglog.predict_proba(X_test)
fpr, tpr, thresholds = roc_curve(y_test, proba[:, 1], pos_label=1, drop_intermediate=False)

fig, ax = plt.subplots(1, 1, figsize=(6,6))
ax.plot([0, 1], [0, 1], 'k--')
# aucf = roc_auc_score(y_test == clr.classes_[0], probas[:, 0]) # première méthode
aucf = auc(fpr, tpr)  # seconde méthode
ax.plot(fpr, tpr, label='auc=%1.5f' % aucf)
ax.set_title('Courbe ROC')
ax.text(0.5, 0.3, "plus mauvais que\nle hasard dans\ncette zone")
ax.legend();

# %% [markdown]
# #### predict

# %%
#reglog.predict([[]])

# %%
model.predict_proba(X_test)
# Out:
# array([[0.47959077, 0.52040923],
#        [0.48096533, 0.51903467],
#        [0.99079394, 0.00920606],
#        ...,
#        [0.3152206 , 0.6847794 ],
#        [0.31721638, 0.68278362],
#        [0.99811432, 0.00188568]])

# %% [markdown]
# ### DecisionTreeClassifier

# %% [markdown]
# ### ExtraTreesClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
xdt2 = ExtraTreesClassifier(max_depth=5, n_estimators=100, class_weight='balanced', n_jobs=-1)
xdt2.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight='balanced',
#                      criterion='gini', max_depth=5, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
predicted_xdt2=xdt2.predict(features_test)
expected = target_test

# %%
# Prédictions sur le test set
y_pred_xdt2 = xdt2.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_xdt2))
# Out:
# 0.7209188060434836

# %%
print(classification_report(expected, predicted_xdt2,target_names=['<=50k', '>50k']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-285-69df708a27a9> in <module>
# ----> 1 print(classification_report(expected, predicted_xdt2,target_names=['<=50k', '>50k']))
#       2 print(confusion_matrix(expected, predicted_xdt2))
#
# NameError: name 'expected' is not defined

# %%
print(confusion_matrix(expected, predicted_xdt2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-280-50fc245e9fed> in <module>
# ----> 1 xdt2.best_params_
#
# AttributeError: 'ExtraTreesClassifier' object has no attribute 'best_params_'

# %% [markdown]
# ### KFold

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
knn = KNeighborsClassifier(n_neighbors=30)

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(knn, X, y, cv=10)

# %%
scores
# Out:
# array([0.84818685, 0.84296251, 0.85310387, 0.84572833, 0.84419176,
#        0.85771358, 0.84665028, 0.85736243, 0.85459576, 0.85459576])

# %%
knn.fit(X,y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=30, p=2,
#                      weights='uniform')

# %%
YtestPred = knn.predict(X_test)

# %%
YtestPred
# Out:
# array([-1, -1, -1, ..., -1, -1, -1], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,YtestPred)
# Out:
# 0.7674247080516288

# %% [raw]
# # KFold avec autant de groupes que d'individus = LeaveOneOut
# cv = KFold(len(y), random_state=0)
# cross_val_score(KNeighborsClassifier(), X, y, cv=cv)

# %% [markdown]
# ## pipeline

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# %%
## List continuous
conti_features =

# %%
preprocess = make_column_transformer(
    (conti_features, StandardScaler()),
    ### Need to be numeric not string to specify columns name 
    (categorical_features, OneHotEncoder(sparse=False))
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-134-31cfbf0560f4> in <module>
#       1 preprocess = make_column_transformer(
# ----> 2     (conti_features, StandardScaler()),
#       3     ### Need to be numeric not string to specify columns name
#       4     (categorical_features, OneHotEncoder(sparse=False))
#       5 )
#
# NameError: name 'conti_features' is not defined

# %%
preprocess.fit_transform(X_train).shape

# %%
model = make_pipeline(
    preprocess,
    LogisticRegression())

# %%
model.fit(X_train, y_train)
print("logistic regression score: %f" % model.score(X_test, y_test))

# %%
model.predict_proba(X_test)

# %% [markdown]
# ## GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### reg log

# %%
penalty = ['l1', 'l2']
C = np.logspace(0, 4, 10)
random_state=[0]
hyperparameters = dict(C=C, penalty=penalty, 
                  random_state=random_state)

model = reglog

# %%
clf = GridSearchCV(estimator = model, param_grid = hyperparameters, 
                   cv=5)
best_model = clf.fit(X_train, y_train)
print('Best Penalty:', best_model.best_estimator_.get_params() ['penalty'])
print('Best C:', best_model.best_estimator_.get_params()['C'])
# Out:
# Best Penalty: l1
# Best C: 1.0

# %% [markdown]
# ### KNN

# %%
model = KNeighborsRegressor()

hyperparameters = dict('n_neighbors': list(range(1,21))

# %% [raw]
# cvgrid = GridSearchCV(estimator=model, param_grid=hyperparameters,
#                scoring='neg_mean_squared_error',
#                return_train_score=False,
#                cv=StratifiedKFold(n_splits=5, shuffle=True))

# %% [raw]
# grid.fit(X_train, y_train)

# %% [raw]
# grid.best_params_

# %% [raw]
# grid.score(X_test, y_test)

# %% [raw]
# from sklearn.model_selection import GridSearchCV
# from sklearn.linear_model import LogisticRegression
# param_grid = {'C': [0.001, 0.01, 0.1, 1, 10], "penalty":["l1","l2"]}
# grid = GridSearchCV(LogisticRegression(), param_grid, cv=5)
# grid.fit(X_train, y_train)
#
# print("Best cross-validation score: {:.2f}".format(grid.best_score_))
# print("Best parameters: ", grid.best_params_)
# print("Best estimator: ", grid.best_estimator_)

# %%
from sklearn.model_selection import GridSearchCV

grid={'C': [1, 10], "penalty":["l1","l2"]}# l1 lasso l2 ridge

logreg_cv=GridSearchCV(reglog,grid,cv=10)
logreg_cv.fit(X,y)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='auto',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='liblinear',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [1, 10], 'penalty': ['l1', 'l2']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
grid.best_params_

# %% [raw]
# import matplotlib.pyplot as plt
# import mglearnmglearn.tools.visualize_coefficients(grid.best_estimator_.coef_, feature_names, n_top_features=25)
# plt.show()

# %% [markdown]
# ## liens

# %% [markdown]
# * https://github.com/itdxer/adult-dataset-analysis/blob/master/Classification.ipynb
# * https://www.guru99.com/scikit-learn-tutorial.html
# * https://www.kaggle.com/danilopolidoro/adult-prediction-with-knn
# * https://edisciplinas.usp.br/pluginfile.php/4821094/course/section/5863999/Aula%20-%20Testando%20kNN%20com%20a%20base%20adult.html
